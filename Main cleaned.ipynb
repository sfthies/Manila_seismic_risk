# %% [markdown]
# # Manila Seismic Risk Beneficiaries
#
# This script...
# - matches selected schools and health care facilities to all available schools and health care facilities
# - prepares gridded population density data
# - runs IDW to evaluate demand for each school

# %% [markdown]
# Load modules and packages:

# %%
import pandas as pd
import geopandas as gpd
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload

# %%
from bokeh.plotting import save, figure, show
from bokeh.models import GeoJSONDataSource
from bokeh.tile_providers import CARTODBPOSITRON, get_provider

# %%
sys.path.append("C://Users/wb555300/OneDrive - WBG/Documents/GitHub/GOSTnetAddons/")
sys.path.append("C://Users/wb555300/OneDrive - WBG/Documents/GitHub/GOST_PublicGoods/GOSTNets/GOSTNets")
import GOSTnet as gn
import GostnetAddons as gna

# %%
#For plotting:
from mpl_toolkits.axes_grid1 import make_axes_locatable

SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# Set working directory:

# %%
os.chdir('C://Users/wb555300/OneDrive - WBG/Manila_Seismic/')

# %% [markdown]
# Decide on crs for projections:

# %%
proj_crs = {'init': 'epsg:' + str(3123)}
lonlat_crs = {'init': 'epsg:' + str(4326)}

# %% [markdown]
# **Read data**
# - on hospitals:

# %%
#manila hospitals:
mani_hos = gpd.read_file('DATA/For_WB_Schools_Hospitals/MetroManila/MetroManila/DOH/HealthFacilities.shp')
#greater manila hospitals:
gmma_hos = gpd.read_file('DATA/For_WB_Schools_Hospitals/GMMA/DOH/HealthFacilities.shp')

# %% [markdown]
# - on schools

# %%
#manila schools:
mani_sch = gpd.read_file('DATA/For_WB_Schools_Hospitals/MetroManila/MetroManila/DepEd/SchoolLocation.shp')
#greater manila schools:
gmma_sch = gpd.read_file('DATA/For_WB_Schools_Hospitals/GMMA/DepEd/SchoolLocation.shp')

# %% [markdown]
# - on officially selected buildings:

# %%
#officially selected buildings:
selec_buil = gpd.read_file('DATA/1287_Eligible_Buildings_Location/1287_Eligible_Buildings_Location.shp')
#Hospitals:
selec_hos = selec_buil[selec_buil['Type_Occup']=='Hospitals and Facilities']
#Schools:
selec_sch = selec_buil[selec_buil['Type_Occup']=='Schools and Facilities']

# %% [markdown]
# With respect to the complete data sets we focus on manila schools and manila hospitals, as we are not interested in the greater manila area

# %% [markdown]
# For some schools there are multiple buildings at the same location
# -> **identify unique locations**:

# %%
# unique school locations:
selec_sch_u = selec_sch.drop_duplicates(['geometry'])

# unique hospital locations:
selec_hos_u = selec_hos.drop_duplicates(['geometry'])

# %%
# Number of selected schools or rather selected school buildings:
print('Number of school buildings:', (len(selec_sch)))
print('Number of unique school locations:', (len(selec_sch_u)))
print('Total number of schools in Manila:', len(mani_sch),'\n')

# Number ofs elected hospitals or rather selected hospital buildings:
print('Number of hospital buildings:', (len(selec_hos)))
print('Number of unique hospital locations:', (len(selec_hos_u)))
print('Total number of hospitals in Manila:', len(mani_hos))
# Out:
# Number of school buildings: 1185
# Number of unique school locations: 406
# Total number of schools in Manila: 768
#
# Number of hospital buildings: 102
# Number of unique hospital locations: 37
# Total number of hospitals in Manila: 734

# %% [markdown]
# Project to metric projection:

# %%
selec_sch_u_p = selec_sch_u.to_crs(proj_crs)
selec_hos_u_p = selec_hos_u.to_crs(proj_crs)

mani_sch_p = mani_sch.to_crs(proj_crs)
mani_hos_p = mani_hos.to_crs(proj_crs)

# %% [markdown]
# Save data in csv for further processing:

# %%
selec_sch.drop(columns ='geometry').to_csv('DATA/Hospitals_Schools_csv/selected_schools.csv')
selec_hos.drop(columns ='geometry').to_csv('DATA/Hospitals_Schools_csv/selected_hospitals.csv')

mani_sch.drop(columns = 'geometry').to_csv('DATA/Hospitals_Schools_csv/all_schools.csv')
mani_hos.drop(columns = 'geometry').to_csv('DATA/Hospitals_Schools_csv/all_hospitals.csv')

# %% [markdown]
# ## Match schools and hospitals

# %% [markdown]
# Since the IDW needs to be done on all schools and hospitals but we are interested in the demand for selected schools and hospitals only, we need to match the respective data frames:

# %% [markdown]
# ### First approach: spatial NN mapping

# %% [markdown]
# Define some functions to perform spatial NN mapping:

# %%
def prepend(list, str): 
      
    # Using format() 
    str += '{0}'
    list = [str.format(i) for i in list] 
    return(list)

# %%
def nn_index(gdf1,gdf2, k = 1):
    """
    Function that takes a spatial point gdf1 and returns indices and distances
    of k nearest neighbors in spatial point gdf2 
    """
    gd1 = gdf1.copy()
    gd2 = gdf2.copy()
           
    ## NN lookup
    #Import spatial from scipy for very quick NN lookup:
    from scipy import spatial
    
    G_tree = spatial.KDTree(np.array([gd2.geometry.x, gd2.geometry.y]).T)
    distances, indices = G_tree.query(np.array([gd1.geometry.x, gd1.geometry.y]).T, k = k)
    
    indici = gd2.index.values[indices]
    
    col_names = prepend(np.arange(1,k+1,1).astype(str), 'index_k_') + prepend(np.arange(1,k+1,1).astype(str), 'dist_k_')
    
    result = pd.DataFrame(np.column_stack([indici, distances]), columns= col_names, index = gd1.index)
    result[prepend(np.arange(1,k+1,1).astype(str), 'index_k_')]= result[prepend(np.arange(1,k+1,1).astype(str), 'index_k_')].astype(int)
    
    return result

# %% [markdown]
# **Distances to nearest neighbors:**

# %% [markdown]
# For hospitals:

# %%
nn_index(selec_hos_u_p,mani_hos_p, k = 1).iloc[:,1].hist()
plt.show()

# %% [markdown]
# For schools:

# %%
nn_index(selec_sch_u_p,mani_sch_p, k = 1).iloc[:,1].hist(bins = np.arange(0,1700,100))
plt.show()

# %% [markdown]
# *The majority of hospitals and schools are further than 100 metres from their nearest neighbors*
#
# Furthermore multiple locations are mapped to the same buildings; taking for example hospitals there are 37 unique hospitals in the data, but they are mapped to only 30 hospitals in the 'full' dataset.

# %%
print('Number of hospitals selected for upgrade:', len(selec_hos_u_p))
print('Number of hospitals these are mapped to:', len(gna.unique(nn_index(selec_hos_u_p,mani_hos_p, k = 1)['index_k_1'])))
print('Unique mappings occur 25 times \n duplications occur 4 times and \n a "quadrication" occurs 1 time')

nn_index(selec_hos_u_p,mani_hos_p, k = 1)['index_k_1'].value_counts().value_counts()
# Out:
# Number of hospitals selected for upgrade: 37
# Number of hospitals these are mapped to: 30
# Unique mappings occur 25 times
#  duplications occur 4 times and
#  a "quadrication" occurs 1 time
# 1    25
# 2     4
# 4     1
# Name: index_k_1, dtype: int64

# %% [markdown]
# For schools we have the following:

# %%
print('Number of schools selected for upgrade:', len(selec_sch_u))
print('Number of schools these are mapped to:', len(gna.unique(nn_index(selec_sch_u_p,mani_sch_p, k = 1)['index_k_1'])))

nn_index(selec_sch_u_p,mani_sch_p, k = 1)['index_k_1'].value_counts().value_counts()
# Out:
# Number of schools selected for upgrade: 406
# Number of schools these are mapped to: 296
# 1    215
# 2     58
# 3     19
# 5      2
# 4      2
# Name: index_k_1, dtype: int64

# %% [markdown]
# **Do mapping anyway and see if & when names agree:**
#
# For hospitals:

# %%
#Index of nearest neighbors:
NN_hos_index = nn_index(selec_hos_u_p,mani_hos_p, k = 1)['index_k_1']

#Select columns used for merging:
cols = ['facilityn','healthf1', 'ownership', 'ownership1', 'sourcelat', 'precision', 'bedcapacit', 'grassess', 'notes', 'geometry']

#Merge (i.e. add the information form the NN to the selected data frame)
selec_hos_u_p_combn = selec_hos_u_p.reset_index().merge(mani_hos_p.loc[NN_hos_index, cols].reset_index().add_prefix('NN_'), left_index = True, right_index = True)

# %% [markdown]
# Compare names manually:

# %% [raw]
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(selec_hos_u_p_combn[['Building_N', 'NN_facilityn']])

# %% [markdown]
# Do the same for schools:

# %%
#Function to compare school names more easily:
def extract_school_name(x):
    temp_list = x.upper().split(',')
    temp_iden = list(map(lambda y: 'SCHOOL' in y, temp_list))
    if np.any(temp_iden):
        temp = np.where(temp_iden)[0]
        return np.array(temp_list)[temp][0].strip()
    else:
        return x

# %%
#Index of nearest neighbors:
NN_sch_index = nn_index(selec_sch_u_p,mani_sch_p, k = 1)['index_k_1']
NN_sch_dist = nn_index(selec_sch_u_p,mani_sch_p, k = 1)['dist_k_1']

#Select columns used for merging:
cols = ['schoolname','enrollment', 'mooeinph', 'offering', 'geometry', 'datasource']

#Merge (i.e. add the information form the NN to the selected data frame)
selec_sch_u_p_combn = selec_sch_u_p.reset_index().merge(mani_sch_p.loc[NN_sch_index, cols].reset_index().add_prefix('NN_'), left_index = True, right_index = True)

#add distance to NN:
selec_sch_u_p_combn['NN_dist'] = NN_sch_dist.reset_index(drop = True)

# %%
selec_sch_u_p_combn['School_N'] = selec_sch_u_p_combn['Building_N'].apply(extract_school_name)

# %% [raw]
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(selec_sch_u_p_combn[['School_N','NN_schoolname', 'NN_dist', 'NN_datasource']])

# %% [markdown]
# Spatial mapping  does not work as well as hoped! Next...

# %% [markdown]
# ### Second approach: Mapping based on names

# %% [markdown]
# School and hospital names could be used for mapping, but they are not in a clean format. Therefore, write a function that cleans the name:

# %%
import string
def clean_name(name, replace_dict = {}, to_upper = True):
    new_name = []
    #remove punctuation:
    name = ''.join([char for char in name if char not in string.punctuation])
    #Go through every word in the old name and adjust it
    for word in name.split():
        word = word.strip()
        if word in replace_dict:
            word = replace_dict[word]
        if to_upper == True:
            word = word.upper()
        new_name.append(word)
    new_name = ' '.join(new_name)
    return new_name

# %% [markdown]
# And a function that does NN neighbor matching on strings:

# %%
import jellyfish as jf
def string_NN_map(names1, names2, k, dist_fun = jf.jaro_winkler):
    """
    Function that takes a pd.Series of names1 and returns for each element the closest k names in the pd.Series names2
    as measured by teh specified distance function. Default: jaro winkler
    """
    names1_ind = names1.index
    names2_ind = names2.index
    
    #calculate distances:
    dist_mat = np.array([[jf.jaro_winkler(word1, word2) for word2 in list(names2)] for word1 in list(names1)])
    
    #obtain location indicies of k nearest neighbors (taking into account that sort orders increasingly):
    k_NN_iloc = np.flip(dist_mat.argsort(axis = 1)[:,-k:], axis =1)
    
    #obtain actual indicies of k nearest neighbors:
    k_NN_loc = names2_ind.values[k_NN_iloc]
    
    #translate indicies to names:
    k_NN_names = np.apply_along_axis(lambda x: names2.loc[x], 1, k_NN_loc)
    
    #obtain distance to k NN:
    k_NN_dist = np.array([list(dist_mat[x, k_NN_iloc[x,:]]) for x in np.arange(dist_mat.shape[0])])
    
    #Store results in pandas data frame
    #Prepare column names:
    col_names = prepend(np.arange(1,k+1,1).astype(str), 'index_k_') + prepend(np.arange(1,k+1,1).astype(str), 'name_k_') + prepend(np.arange(1,k+1,1).astype(str), 'dist_k_')
    #prepare result:
    result = pd.DataFrame(np.column_stack([k_NN_loc, k_NN_names, k_NN_dist]), columns = col_names, index = names1_ind)
    
    return result

# %% [markdown]
# **Semi manual merging of schools**

# %% [markdown]
# Function to extract school name from name column:

# %%
def extract_school_name(x):
    temp_list = x.upper().split(',')
    temp_iden = list(map(lambda y: 'SCHOOL' in y, temp_list))
    if np.any(temp_iden):
        temp = np.where(temp_iden)[0]
        return np.array(temp_list)[temp][0].strip()
    else:
        return x

# %%
#pd.Series of names from first data source:
names1 = selec_sch_u_p['Building_N'].apply(extract_school_name).apply(clean_name)

# %%
#pd.Series of names from second data source:
names2 = mani_sch_p['schoolname'].apply(clean_name, replace_dict = {'ES': 'elementary school', 
                                                           'HS': 'high school',
                                                           'NHS': 'national high school'})

# %% [markdown]
# Do matching based on names for schools:

# %%
school_nn_names = string_NN_map(names1, names2, k = 5)

# %% [markdown]
# Add matching based on spatial distance as support:

# %%
school_nn_dist = nn_index(selec_sch_u_p, mani_sch_p, k = 3)

# %%
for x in np.arange(3):
    school_nn_dist['name_k_'+str(x+1)] =  np.array(mani_sch_p['schoolname'].loc[school_nn_dist['index_k_'+str(x+1)]])

# %% [markdown]
# Combine all results in one data set to be manually merged:

# %%
man_merge_school = pd.concat([names1, school_nn_names, school_nn_dist.add_prefix('sp_')], axis = 1)

man_merge_school.to_csv('DATA/Hospitals_Schools_csv/school_man_merge.csv')

# %% [markdown]
# Quick evaluation how well the mapping on names has worked:

# %%
#For how many do we have a perfect string match:
print('Perfect sring match for:', round((man_merge_school['dist_k_1']==1).mean(),4))

#For how many do spatial & string matches agree:
print('Spatial & string match for:', round((man_merge_school['index_k_1']==man_merge_school['sp_index_k_1']).mean(), 4))
# Out:
# Perfect sring match for: 0.569
# Spatial & string match for: 0.3399

# %% [markdown]
# Check for how many schools merges are duplicated:

# %%
man_merge_school_res['MATCHED_INDEX'].value_counts()[man_merge_school_res['MATCHED_INDEX'].value_counts()>1].sum()
# Out:
# 123

# %% [markdown]
# **Semi manual merges for hospitals**

# %%
def hos_name_extract(name):
    try:
        return name.split(',')[1]
    except:
        return name

# %% [markdown]
# Add spatial and string NN:

# %%
hos_nn_dist = nn_index(selec_hos_u_p, mani_hos_p, k = 3)
for x in np.arange(3):
    hos_nn_dist['name_k_'+str(x+1)] =  np.array(mani_hos_p['facilityn'].loc[hos_nn_dist['index_k_'+str(x+1)]])

# %%
names1 = selec_hos_u_p['Building_N']
names2 = mani_hos_p['facilityn']

man_merge_hos = pd.concat([selec_hos_u_p['Building_N'], string_NN_map(names1, names2, k = 3), hos_nn_dist], axis =1)

man_merge_hos.to_csv('DATA/Hospitals_Schools_csv/hos_man_merge.csv')

# %% [markdown]
# ### Read results from manual merging:

# %%
#Schools
man_merge_school_res = pd.read_csv('DATA/Hospitals_Schools_csv/school_man_merge_res.csv')
man_merge_school_res = man_merge_school_res.set_index('Index')

# %%
#Hospitals:
man_merge_hos_res = pd.read_csv('DATA/Hospitals_Schools_csv/hos_man_merge_res.csv')
man_merge_hos_res = man_merge_hos_res.rename(columns = {'Unnamed: 0':'Index'}).set_index('Index')

# %%
selected_school_indices = gna.unique(man_merge_school_res['MATCHED_INDEX'])
selected_hos_indices = gna.unique(man_merge_hos_res['MATCHED_INDEX'])

# %% [markdown]
# Add an identifier to the complete data frame which informs about selection:

# %%
mani_sch_p['selected'] =np.isin(mani_sch_p.index, selected_school_indices)
mani_hos_p['selected'] =np.isin(mani_hos_p.index, selected_hos_indices)

# %% [markdown]
# ## Read and prepare population density data

# %% [markdown]
# Read shapefile of municipalities:

# %%
philippines = gpd.read_file('DATA/City_Municipality_Boundaries/City_Municipality_Boundaries.shp')

# %% [markdown]
# Define Area of Interest:

# %%
AOI = philippines[philippines['ADM1_EN']=='National Capital Region']
AOI_p = AOI.to_crs(proj_crs)

# %% [markdown]
# Save figure of area of interest:

# %%
fig, ax = plt.subplots(figsize = (10,10))
AOI.plot(ax = ax, edgecolor = 'lightblue', color='FireBrick')
ax.set_facecolor('lightblue')
plt.savefig('PLOTS/AOI.jpg',  bbox_inches='tight')

# %% [markdown]
# Read barangay level population data on OSM building footprints:

# %%
building_pop = gpd.read_file('DATA/MetroManila_PopDensity/Buildings_Brgy.shp')

# %%
building_pop.head()
# Out:
#          munname     bgyname  Bgy_Popula  PopDen_Bgy      AREA_GEO  \
# 0  CALOOCAN CITY  Barangay 1        2417    0.153415  15754.633917
# 1  CALOOCAN CITY  Barangay 2        5134    0.177915  28856.442389
# 2  CALOOCAN CITY  Barangay 3        2621    0.107641  24349.558870
# 3  CALOOCAN CITY  Barangay 4        2809    0.166453  16875.591804
# 4  CALOOCAN CITY  Barangay 5        3004    0.125106  24011.726009
#
#                                             geometry
# 0  MULTIPOLYGON Z (((120.97341 14.65761 0.00000, ...
# 1  MULTIPOLYGON Z (((120.97106 14.65980 0.00000, ...
# 2  MULTIPOLYGON Z (((120.97276 14.65780 0.00000, ...
# 3  MULTIPOLYGON Z (((120.97047 14.65820 0.00000, ...
# 4  MULTIPOLYGON Z (((120.97199 14.65525 0.00000, ...

# %% [markdown]
# Make a plot of the population data using the OSM footprint (**takes very long**):

# %%
fig, ax = plt.subplots(figsize = (10,10))
building_pop.plot(ax = ax, column = 'PopDen_Bgy',  legend = True,  cmap='OrRd', scheme = "fisherjenkssampled")
plt.savefig('PLOTS/Bgy_Pop_Build.jpg',  bbox_inches='tight')
# Out:
# C:\WBG\Anaconda3\envs\conn\lib\site-packages\mapclassify\classifiers.py:482: UserWarning: Deprecated (2.1.0): Fisher_Jenks is being renamed to FisherJenks. Fisher_Jenks will be removed on 2020-01-31.
#   warn(self.message)

# %% [markdown]
# Map to metric projection:

# %%
building_pop_p = building_pop.to_crs(proj_crs)

# %% [markdown]
# **Define grid**

# %%
grid_p = gpd.GeoDataFrame(geometry = gna.make_fishnet(AOI_p, 500))
# Out:
# Number of cols 56 . Number of rows 102

# %% [markdown]
# Determine population per grid cell:

# %%
reload(gna)
# Out:
# <module 'GostnetAddons' from 'C://Users/wb555300/OneDrive - WBG/Documents/GitHub/GOSTnetAddons\\GostnetAddons.py'>

# %% [markdown]
# Take the actual building level data and run calculations:

# %% [raw]
# %time grid_p['Pop_build']=gna.area_weighted_aggregation(grid_p, building_pop_p, ['Bgy_Popula'])

# %% [raw]
# # Adjust nan values:
# grid_p.loc[np.isnan(grid_p['Pop_build']), 'Pop_build'] = 0

# %% [markdown]
# ... or alternatively **load the result from previous runs of this code:**

# %%
grid = gpd.read_file('DATA/Manila_Gridded_Population/manila_gridded_pop.shp')
grid_p = grid.to_crs(proj_crs)

# %% [markdown]
# Get an overview of the population density and save:

# %%
fig, ax = plt.subplots(figsize = (10,10))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
ax.set_facecolor('lightblue')
grid_p.to_crs(lonlat_crs).plot(ax = ax, column = 'Pop_build',  legend = True,  cmap='OrRd', cax = cax)
plt.savefig('PLOTS/Grid_Pop.jpg',  bbox_inches='tight')

# %% [markdown]
# Check whether gridded aggregates agree with non gridded aggregates:

# %%
grid_p[['Pop_build']].sum()/building_pop_p['Bgy_Popula'].sum()
# Out:
# Pop_build    0.999966
# dtype: float64

# %% [markdown]
# The latter aggreation method deviates by less than 0.01% -> good!
#
# Store the result (not necessary anymore in later iterations of the code)

# %% [raw]
# grid_p.to_crs(lonlat_crs).to_file('DATA/Gridded_Population/manila_gridded_pop.shp')

# %% [markdown]
# Total population:

# %%
grid_p['Pop_build'].sum()
# Out:
# 12876810.4886881

# %% [markdown]
# Calculate relative population:

# %%
grid_p['Pop_rel'] = grid_p['Pop_build']/grid_p['Pop_build'].sum()

# %% [markdown]
# ## Prepare inverse distance weighting for schools

# %%
def inverse_weighting(origin, origin_column, target, dist_thres, k, p = 1, map_to_nn = True):
    """
    Assigns spatial data contained in the origin data frame to the target data frame based on inverse distance weighting.
    ---------
    Arguments:
    
    origin: A spatial points geopandas.GeoDataFrame object with valid geometry column
    origin_column: the respective column in the origin data frame to be mapped
    target: a spatial points geopandas.GeoDataFrame object with valid geometry column
    dist_thres: A distance threshold in metres. Nearest neighbors beyond the threshold won't be considered for mapping
    k: number of nearest neighbors used for mapping
    p: Minkowski distance used for weight calculation (default = 2)
    map_to_nn: logical, if True and all neighbors further than dist_thres away, all data will be mapped to closest neighbor
                        if False an error message is produced    
    ---------
    """
    
    #Calculate indices and distances to k NN:
    temp_index_dist = nn_index(origin, target, k = k)
    
    #Set up vector to store results:
    results = pd.Series(0, index = target.index)
    
    to_nn_count = 0
    
    for ind, row in temp_index_dist.iterrows():
        #Select distances
        temp_dists = row.iloc[-k:]
        
        #Filter valid distances:
        if sum(temp_dists < dist_thres)>0:
            valid_temp_dists = temp_dists[temp_dists < dist_thres]
        else:
            if map_to_nn == True:
                valid_temp_dists = pd.Series(temp_dists[0])
                to_nn_count += 1
            else:
                return print('No neighbor within the distance threshold for origin: ', ind)
        
        #Calculate weights:
        temp_weights = valid_temp_dists**(-p)
        
        #Calculate values:
        temp_values = temp_weights*origin.loc[ind,origin_column]/temp_weights.sum()
        #and adjust their indices:
        temp_values.index = list(row.iloc[:len(valid_temp_dists)].astype(int))
        
        #Add values to the result column:
        results.loc[temp_values.index] += temp_values
        
    print(to_nn_count, ' values were mapped to their single nearest neighbor\n')
        
    return results

# %% [markdown]
# Generate a copy of the school data set to store results:

# %%
# Generate a copied school data set:
mani_sch_p_demand = mani_sch_p.loc[:,['objectid', 'schoolid', 'schoolname', 'division', 'district','offering', 'selected', 'geometry']].copy()

# %% [markdown]
# ### Add columns for population in school age, primary school age and high school age:
#
# 1. Based on **UN DESA** Population estimates for 2020 the age structure in the Philippines is the following:
#
# | Group | Percentage of total population |
# | --- | --- |
# | School age (6-18) | 25.91% |
# | Elementary school age (6-12) | 12.3 % |
# | Secondary school age (13-18) | 13.6 % |

# %% [markdown]
# 2. With respect to the **2015 census** the age structure is the following in the Metro Manila area
#
# Source: [https://www.citypopulation.de/en/philippines/admin/13__metro_manila/](https://www.citypopulation.de/en/philippines/admin/13__metro_manila/)
#
# *Unfortuantely I was unable to find a more detailed population overview by age group - even though I believe they should be included in the 2015 census, but tables were not available*

# %% [markdown]
# | Group | Percentage of total population |
# | --- | --- |
# | School age (6-18) | 24.04 % |
# | Elementary school age (6-12) | 12.91 % |
# | Secondary school age (13-18) | 11.13 % |

# %% [markdown]
# 3. Combining the **April 2020 PSA quickstats** which informs about actual school enrollment in 2018 with total population estimates for 2018, the percentage school enrollment per school type is the following:
#
# Source:
# - [Quickstat April 2020](https://psa.gov.ph/statistics/quickstat/national-quickstat/all/*)
# - [Total population estimates](https://psa.gov.ph/sites/default/files/attachments/hsd/pressrelease/Table4_9.pdf)

# %% [markdown]
# | Group | Percentage of total population |
# | --- | --- |
# | School enrollment | 23.07 % |
# | Elementary school enrollment | 12.44 % |
# | Secondary school enrollment | 10.64 % |

# %% [markdown]
# Let's use the last estimate for the remaining calculations:

# %%
grid_p['Pop_school'] = grid_p['Pop_build'] * 0.2307
grid_p['Pop_elem_school'] = grid_p['Pop_build'] * 0.1244
grid_p['Pop_seco_school'] = grid_p['Pop_build'] * 0.1064

# %% [markdown]
# Generate a copy of the grid based on centroids:

# %%
grid_p_cent = grid_p.copy()
grid_p_cent['geometry']= grid_p_cent.centroid

# %% [markdown]
# **Add the respective school demand using different types of inverse weighting**

# %% [markdown]
# First, lets get an idea for the average ratio of pupils per school:

# %%
#Overall Population:
grid_p_cent['Pop_build'].sum()
# Out:
# 12876810.4886881

# %%
print('Potential pupils in Manila:', round(grid_p_cent['Pop_school'].sum()))
print('Number of schools:', len(mani_sch_p))
print('Pupils per school:', round(grid_p_cent['Pop_school'].sum()/len(mani_sch_p)))
# Out:
# Potential pupils in Manila: 2970680.0
# Number of schools: 768
# Pupils per school: 3868.0

# %% [markdown]
# This indicates that on average, each school would need to host more than 3800 pupils!
# Potential error sources:
# - not all schools in data set
# - age structure in Manila is very different from the age structure in the remaining Philippines

# %% [markdown]
# #### Start with IDW mapping of all schools

# %%
# p=1
#5 NN within 10 km
# %time mani_sch_p_demand['dist:10_k:5_p:1'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = 5)

#10 NN within 10 km
# %time mani_sch_p_demand['dist:10_k:10_p:1'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = 10)

#All NN within 10 km
# %time mani_sch_p_demand['dist:10_k:inf_p:1'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = len(mani_sch_p_demand))


# p= 0
#5 NN within 10 km
# %time mani_sch_p_demand['dist:10_k:5_p:0'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = 5, p = 0)

#10 NN within 10 km
# %time mani_sch_p_demand['dist:10_k:10_p:0'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = 10, p = 0)

#All NN within 10 km
# %time mani_sch_p_demand['dist:10_k:inf_p:0'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = len(mani_sch_p_demand), p = 0)


# p= 2
#5 NN within 10 km
# %time mani_sch_p_demand['dist:10_k:5_p:2'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = 5, p = 2)

#10 NN within 10 km
# %time mani_sch_p_demand['dist:10_k:10_p:2'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = 10, p = 2)

#All NN within 10 km
# %time mani_sch_p_demand['dist:10_k:inf_p:2'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 10000 , k = len(mani_sch_p_demand), p = 2)


# p= 1
#NN only, no distance disthold
# %time mani_sch_p_demand['dist:inf_k:1_p:1'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres= np.inf, k = 1, p = 1)

#All NN within 2 km
# %time mani_sch_p_demand['dist:2_k:5_p:1'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 2000 , k = len(mani_sch_p_demand), p = 1)

#5 NN within 5 km
# %time mani_sch_p_demand['dist:5_k:5_p:1'] =  inverse_weighting(grid_p_cent, 'Pop_school', mani_sch_p_demand, dist_thres = 5000 , k = len(mani_sch_p_demand), p = 1)
# Out:
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.65 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.75 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 46 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.63 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.94 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 38.8 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.61 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.91 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 39.2 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.48 s
# 55  values were mapped to their single nearest neighbor
#
# Wall time: 37.8 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 38 s

# %% [markdown]
# Check if all mappings result in the same population totals:

# %%
mani_sch_p_demand.sum()
# Out:
# objectid                                                4514119
# schoolid                                              150506201
# schoolname    E. delos Santos Elementary SchoolEulogio Rodri...
# division      ManilaManilaManilaManilaManilaManilaManilaMani...
# district      SingalongSta. Ana ISan AndresMalatePaco ITondo...
# offering      ESSSESSSSSSSESSSESESSSESESESESESSSESSSESSSESSS...
# selected                                                    337
# dtype: object

# %% [markdown]
# And let's analyse the different distributions of pupils per school:

# %%
mani_sch_p_demand.iloc[:,-12:].hist(bins = np.arange(0,30000,1000), figsize = (15,15), sharey = True)
plt.savefig('PLOTS/School_size_hists.jpg', bbox_inches='tight')

# %% [markdown]
# Get a visual impression of population density and school location & demand:

# %%
grid_p['Pop_school'] = grid_p_cent['Pop_school']

# %%
fig, ax = plt.subplots(figsize = (15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
ax.set_facecolor('lightblue')
grid_p.to_crs(lonlat_crs).plot(ax = ax, column = 'Pop_school',  legend = True,  cmap='OrRd', cax = cax)
mani_sch_p_demand.to_crs(lonlat_crs).plot(ax = ax, column = 'dist:10_k:10_p:1', cmap = 'Greens',scheme="fisherjenks" , alpha = 0.8, markersize = 30, legend = True, edgecolor = 'black')
plt.savefig('PLOTS/School_size_map_total.jpg', bbox_inches = 'tight')

# %% [markdown]
# Select only selected schools:

# %%
man_merge_school_res = pd.read_csv('DATA/Hospitals_Schools_csv/school_man_merge_res.csv')
man_merge_school_res = man_merge_school_res.set_index('Index')

# %%
selected_school_indices = gna.unique(man_merge_school_res['MATCHED_INDEX'])

# %%
fig, ax = plt.subplots(figsize = (15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
ax.set_facecolor('lightblue')
grid_p.to_crs(lonlat_crs).plot(ax = ax, column = 'Pop_school',  legend = True,  cmap='OrRd', cax = cax)
mani_sch_p_demand.to_crs(lonlat_crs).loc[selected_school_indices,:].plot(ax = ax, column = 'dist:10_k:10_p:1', cmap = 'Greens',scheme="fisherjenks" , alpha = 0.8, markersize = 100, legend = True, edgecolor = 'black')
plt.savefig('PLOTS/School_size_map_selected.jpg', bbox_inches = 'tight')

# %% [markdown]
# Do the same with the alternative coordinates:

# %% [raw]
# selec_sch_demand = pd.concat([selec_sch_u.reset_index(),mani_sch_p_demand.to_crs(lonlat_crs).loc[list(man_merge_school_res['MATCHED_INDEX']),:].drop(columns = 'geometry').reset_index()],
#           axis = 1,)

# %% [raw]
# fig, ax = plt.subplots(figsize = (15,15))
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.1)
# ax.set_facecolor('lightblue')
# grid_p.to_crs(lonlat_crs).plot(ax = ax, column = 'Pop_build',  legend = True,  cmap='OrRd', cax = cax)
# selec_sch_demand.to_crs(lonlat_crs).plot(ax = ax, column = 'dist:10_k:10_p:1', cmap = 'Greens',scheme="fisherjenks" , alpha = 0.8, markersize = 100, legend = True, edgecolor = 'black')
# #plt.savefig('PLOTS/School_size_map_selected.jpg')

# %% [markdown]
# **Restrict the IDW to Elementary Schools only:**

# %%
mani_es_p_demand = mani_sch_p_demand.loc[mani_sch_p_demand['offering']=='ES'].iloc[:,:8]

# %%
mani_es_p_demand.head()
# Out:
#    objectid  schoolid                                   schoolname division  \
# 0      5455    136476            E. delos Santos Elementary School   Manila
# 2      5457    136479               Rafael Palma Elementary School   Manila
# 6      5461    136477           Aurora A. Quezon Elementary School   Manila
# 8      5463    136474  Dr. Celedonio A. Salvador Elementary School   Manila
# 9      5464    136473               Justo Lukban Elementary School   Manila
#
#      district offering  selected                        geometry
# 0   Singalong       ES     False  POINT (499034.631 1612066.533)
# 2  San Andres       ES     False  POINT (500400.526 1611142.792)
# 6      Malate       ES      True  POINT (498681.828 1611471.640)
# 8     Paco II       ES      True  POINT (499455.519 1612722.066)
# 9      Paco I       ES     False  POINT (499128.324 1612632.510)

# %% [markdown]
# Run algorithm with 10 NN in 10 km radius on population in elementary school age:

# %%
mani_es_p_demand['dist:10_k:10_p:1'] =  inverse_weighting(grid_p_cent, 'Pop_elem_school', mani_es_p_demand, dist_thres = 10000 , k = 10)
# Out:
# 0  values were mapped to their single nearest neighbor

# %% [markdown]
# **Restrict the IDW to Secondary Schools only:**

# %%
mani_ss_p_demand = mani_sch_p_demand.loc[mani_sch_p_demand['offering']=='SS'].iloc[:,:8]

# %% [markdown]
# Run algorithm with 10 NN in 10 km radius on population in secondary school age:

# %%
mani_ss_p_demand['dist:10_k:10_p:1'] =  inverse_weighting(grid_p_cent, 'Pop_seco_school', mani_ss_p_demand, dist_thres = 10000 , k = 10)
# Out:
# 0  values were mapped to their single nearest neighbor

# %% [markdown]
# ### Plot:

# %%
from matplotlib import gridspec

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,10), gridspec_kw={'width_ratios': [3, 3]})

divider = make_axes_locatable(ax2)
cax = divider.append_axes("right", size="5%", pad=0.1)

#ax1.set_facecolor('lightblue')
#ax2.set_facecolor('lightblue')


vmin = min([min(mani_es_p_demand['dist:10_k:10_p:1']), min(mani_ss_p_demand['dist:10_k:10_p:1'])])
vmax = max([max(mani_es_p_demand['dist:10_k:10_p:1']), max(mani_ss_p_demand['dist:10_k:10_p:1'])])

AOI.plot(ax = ax1, color = 'lightgrey')
AOI.plot(ax = ax2, color = 'lightgrey')

mani_es_p_demand.sort_values(by = 'dist:10_k:10_p:1', ascending = False).to_crs(lonlat_crs).plot(column = 'dist:10_k:10_p:1', ax = ax1, vmin = vmin, vmax = vmax, cmap = 'OrRd')
mani_ss_p_demand.sort_values(by = 'dist:10_k:10_p:1', ascending = False).to_crs(lonlat_crs).plot(column = 'dist:10_k:10_p:1', ax = ax2, legend = True, cax = cax, vmin = vmin, vmax = vmax, cmap = 'OrRd')
ax1.title.set_text('Demand for Elementary Schools')
ax2.title.set_text('Demand for Secondary Schools')
plt.subplots_adjust(right = 1.2)
plt.show()

# %% [markdown]
# Distribution of ES or SS demands:

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,4),  sharey = 'all')
mani_es_p_demand['dist:10_k:10_p:1'].hist(ax = ax1, bins = np.arange(0,15000, 1000), color = 'firebrick')
mani_ss_p_demand['dist:10_k:10_p:1'].hist(ax = ax2, bins = np.arange(0,15000, 1000), color = 'firebrick')
ax1.title.set_text('Demand for Elementary Schools')
ax2.title.set_text('Demand for Secondary Schools')
plt.show()

# %% [markdown]
# **Combine data sets:**

# %%
mani_school_demand_p = pd.concat([mani_es_p_demand, mani_ss_p_demand])

# %%
mani_school_demand_p['selected'] = np.isin(mani_school_demand_p.index, selected_school_indices)

# %%
mani_school_demand_p = mani_school_demand_p.rename(columns = {'dist:10_k:10_p:1': 'demand'})

# %%
mani_school_demand_p = mani_school_demand_p.sort_index()

# %% [markdown]
# **Add column with demand to the original, selected school, data frame:**

# %% [markdown]
# First to all unique schools:

# %%
selec_sch_u.reset_index()
temp = mani_school_demand_p.loc[man_merge_school_res.sort_index()['MATCHED_INDEX'].values,:].reset_index(drop = True).to_crs(lonlat_crs).drop(columns = 'selected')
selec_sch_u_demand = pd.concat([selec_sch_u.drop(columns = 'geometry').reset_index(), temp], axis = 1).set_index('index')

# %% [markdown]
# Secondly for all schools:

# %%
temp = selec_sch_u_demand.loc[:,['Lat_Y', 'Lat_X', 'objectid', 'schoolid','schoolname','division','district','offering', 'demand']]
temp_res = selec_sch.merge(temp)
selec_sch_demand = temp_res.set_index(temp_res['Object_ID']-1)

# %% [markdown]
# Save results:

# %%
selec_sch_u_demand.to_file('RESULTS/Unique_Eligible_Schools_Demand.shp')
selec_sch_demand.to_file('RESULTS/All_Eligible_Schools_Demand.shp')

# %% [markdown]
# ### Back of the envelope calculation for beneficiaries of upgrades over lifetime of buildings

# %% [markdown]
# Years spend in elementary school: 6-12, i.e. 7 years, hence every year 1/7 of students are replaced. Over a 30 year building lifetime the upgrade will hence benefit $(1 + \frac{30}{7}) * \text{number of elementary pupils}$, i.e.

# %%
#direct beneficiaries:
es_direct_benificaries = mani_school_demand_p.loc[(mani_school_demand_p['offering']=='ES') &
                        (mani_school_demand_p['selected']==True),'demand'].sum()

#indirect / lifetime benificiaries:
es_indirect_benificaries = es_direct_benificaries*(1+30/7)

print('Direct beneficaries ES investment:', round(es_direct_benificaries), '(',round(es_direct_benificaries/grid_p['Pop_elem_school'].sum()*100,1),'%)')
print('Indirect / lifetime beneficaries ES investment:', round(es_indirect_benificaries))
# Out:
# Direct beneficaries ES investment: 716965.0 ( 44.8 %)
# Indirect / lifetime beneficaries ES investment: 3789671.0

# %% [markdown]
# Years spend in secondary school: 13-18, i.e. 6 years, hence every year 1/6 of students are replaced. Over a 30 year building lifetime the upgrade will hence benefit $(1 + \frac{30}{6}) * \text{number of secondary school pupils}$, i.e.

# %%
#direct beneficiaries:
ss_direct_benificaries = mani_school_demand_p.loc[(mani_school_demand_p['offering']=='SS') &
                        (mani_school_demand_p['selected']==True),'demand'].sum()

#indirect / lifetime benificiaries:
ss_indirect_benificaries = ss_direct_benificaries*(1+30/6)

print('Direct beneficaries SS investment:', round(ss_direct_benificaries),  '(',round(ss_direct_benificaries/grid_p['Pop_seco_school'].sum()*100,1),'%)')
print('Indirect / lifetime beneficaries SS investment:', round(ss_indirect_benificaries))
# Out:
# Direct beneficaries SS investment: 521915.0 ( 38.1 %)
# Indirect / lifetime beneficaries SS investment: 3131490.0

# %%
# Out:
# 1601875.2247927997

# %% [markdown]
# **Plot**

# %%
fig, ax = plt.subplots(figsize = (15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
ax.set_facecolor('lightblue')
grid_p.to_crs(lonlat_crs).plot(ax = ax, column = 'Pop_school',  legend = True,  cmap='OrRd', cax = cax, legend_kwds={'label':'Total population enrolled'})
mani_school_demand_p.to_crs(lonlat_crs).plot(ax = ax, markersize = 1, color = 'black')
mani_es_p_demand[mani_es_p_demand['selected']].to_crs(lonlat_crs).plot(ax = ax, column = 'dist:10_k:10_p:1', cmap = 'Greens',scheme="fisherjenks" , alpha = 0.8, markersize = 100, legend = True, edgecolor = 'black')
mani_ss_p_demand[mani_ss_p_demand['selected']].to_crs(lonlat_crs).plot(ax = ax, column = 'dist:10_k:10_p:1', cmap = 'Greens',scheme="fisherjenks" , alpha = 0.8, markersize = 100, legend = True, edgecolor = 'black', marker = 'P')
plt.savefig('PLOTS/School_size_map_combn.jpg', bbox_inches = 'tight')

# %% [markdown]
# ## Prepare inverse distance weighting for hospitals:

# %% [markdown]
# Given the data set of health care facilities and the population data we can expect the following averages:

# %%
print('Population in Manila:', round(grid_p_cent['Pop_build'].sum()))
print('Number of health care facilities:', len(mani_hos_p))
print('Persons per health care facility:', round(grid_p_cent['Pop_build'].sum()/len(mani_hos_p)))
# Out:
# Population in Manila: 12876810.0
# Number of health care facilities: 734
# Persons per health care facility: 17543.0

# %% [markdown]
# Lets start by doing unspecific distribution, i.e. distribute the entire population on *all* health care facilities, independent of their type. Later we can start to distinguish by hospitals, care centers, etc

# %%
mani_hos_p.columns
# Out:
# Index(['objectid', 'joincount', 'targetfid', 'facilityc', 'healthfac',
#        'facilityn', 'healthf1', 'ownership', 'ownership1', 'streetname',
#        'buildingn', 'zipcode', 'landlinen', 'landline1', 'faxnumber',
#        'emailaddre', 'alternate', 'officialw', 'facilityh', 'facilityp',
#        'latitude', 'longitude', 'sourcelat', 'precision', 'sourcepre',
#        'healthf2', 'serviceca', 'licensing', 'bedcapacit', 'grassess',
#        'eilassess', 'liqassess', 'tsuassess', 'latitudel', 'reasonfor',
#        'approvals', 'datasource', 'dohcode', 'hf1code', 'owncode', 'notes',
#        'globalid', 'creator', 'createdate', 'editor', 'editdate', 'geometry'],
#       dtype='object')

# %%
# New data frame to store results:
mani_hos_p_demand = mani_hos_p[['facilityn', 'healthf1', 'ownership', 'ownership1','bedcapacit','geometry']].copy()

# %%
#Calculate distribution for the following values:
dist_thres_l = [np.inf, 10, 5]
k_l = [5, 10]
p_l = [0, 1,2]

# %%
len(dist_thres_l)*len(k_l)*len(p_l)
# Out:
# 40

# %%
for dist_thres in dist_thres_l:
    for k in k_l:
        for p in p_l:
            # %time mani_hos_p_demand['dist:' + str(dist_thres) + '_k:' + str(k) + '_p:' + str(p)] = inverse_weighting(grid_p_cent, 'Pop_build', mani_hos_p,  dist_thres*1000, k, p)
# Out:
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.59 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.84 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.59 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.92 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.81 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.72 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.53 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.56 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.7 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.77 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.72 s
# 0  values were mapped to their single nearest neighbor
#
# Wall time: 7.86 s
# ...

# %% [markdown]
# Compare distributions of population per hospital for different inverse distance weighting methods:

# %%
mani_hos_p_demand.iloc[:,-(len(dist_thres_l)*len(k_l)*len(p_l)):].hist(figsize = (20,20), sharey = True, bins = np.arange(0,100000,5000))
plt.savefig('PLOTS/Hospital_size_hists.jpg', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize = (15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
ax.set_facecolor('lightblue')
grid_p.to_crs(lonlat_crs).plot(ax = ax, column = 'Pop_build',  legend = True,  cmap='OrRd', cax = cax)
mani_hos_p_demand.to_crs(lonlat_crs).plot(ax = ax, column = 'dist_10_k_10_p_1', cmap = 'Greens',scheme="fisherjenks" , alpha = 0.8, markersize = 30, legend = True, edgecolor = 'black')
plt.savefig('PLOTS/Hospital_size_map_total.jpg', bbox_inches = 'tight')

# %%
## only for selected hospitals:

# %%
man_merge_hos_res = pd.read_csv('DATA/Hospitals_Schools_csv/hos_man_merge_res.csv')
man_merge_hos_res = man_merge_hos_res.rename(columns = {'Unnamed: 0':'Index'}).set_index('Index')

# %%
fig, ax = plt.subplots(figsize = (15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
ax.set_facecolor('lightblue')
grid_p.to_crs(lonlat_crs).plot(ax = ax, column = 'Pop_build',  legend = True,  cmap='OrRd', cax = cax)
mani_hos_p_demand.loc[gna.unique(man_merge_hos_res['MATCHED_INDEX']),:].to_crs(lonlat_crs).plot(ax = ax, column = 'dist_10_k_10_p_1', cmap = 'Greens',scheme="fisherjenks" , alpha = 0.8, markersize = 100, legend = True, edgecolor = 'black')
plt.savefig('PLOTS/Hospital_size_map_selected.jpg', bbox_inches = 'tight')

# %% [markdown]
# # OLD

# %%
sum(man_merge_school['dist_k_1']!=1)
# Out:
# 175

# %%
len(selec_hos_u)
# Out:
# 37

# %%
33.99/56.9
# Out:
# 0.5973637961335677

# %%
#As lists:
names1_l = list(names1)
names2_l = list(names2)

# %%
import string
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

# %%
pd.concat([names1, string_NN_map(names1, names2, k = 5)], axis = 1)
# Out:
#                                            Building_N index_k_1 index_k_2  \
# 0                          PINYAHAN ELEMENTARY SCHOOL       518       392
# 2                          PINYAHAN ELEMENTARY SCHOOL       518       392
# 4          SEDP BUILDING 8CL MANUEL ROXAS HIGH SCHOOL       479       442
# 5                            MANUEL ROXAS HIGH SCHOOL       495        10
# 6                            MANUEL ROXAS HIGH SCHOOL       495        10
# ...                                               ...       ...       ...
# 1258                        NEW ERA ELEMENTARY SCHOOL       504       372
# 1261  ROSA L SUSANO ELEMENTARY SCHOOL QUIRINO HIGHWAY       533       397
# 1265                     SERGIO OSMENA SR HIGH SCHOOL       548        97
# 1267                     TORO HILLS ELEMENTARY SCHOOL       556       474
# 1270                    VILLA VERDE ELEMENTARY SCHOOL       557       262
#
#      index_k_3 index_k_4 index_k_5  \
# 0          199       371       356
# ...

# %%
dist_mat = np.array([[jf.jaro_winkler(word1, word2) for word2 in names2_l] for word1 in names1_l])

# %%
k = 3

# %%
k_NN_iloc = np.flip(dist_mat.argsort(axis = 1)[:,-k:], axis =1)
k_NN_loc = names2_ind.values[k_NN_iloc]

# %%
k_NN_iloc
# Out:
# array([[518, 392, 199],
#        [518, 392, 199],
#        [479, 442, 150],
#        ...,
#        [548,  97,  57],
#        [556, 474,  42],
#        [557, 262, 135]], dtype=int64)

# %%
dist_mat[0, k_NN_iloc[0]]
# Out:
# array([1.        , 0.91480342, 0.90871795])

# %%
# Out:
# array([[1.        , 0.91480342, 0.90871795],
#        [1.        , 0.91480342, 0.90871795],
#        [0.75607726, 0.73948413, 0.73258668],
#        ...,
#        [1.        , 0.83044733, 0.7965368 ],
#        [1.        , 0.89042567, 0.84920635],
#        [1.        , 0.87071306, 0.86870027]])

# %%
np.apply_along_axis(lambda x: names2.loc[x], 1, k_NN_indices)

# %%
k_NN_indices
# Out:
# array([[557, 262, 135],
#        [556, 474,  42],
#        [548,  97,  57],
#        ...,
#        [479, 442, 150],
#        [518, 392, 199],
#        [518, 392, 199]], dtype=int64)

# %%
np.flip(dist_mat[:,-3:])
# Out:
# array([[1.        , 0.87071306, 0.86870027],
#        [1.        , 0.89042567, 0.84920635],
#        [1.        , 0.83044733, 0.7965368 ],
#        ...,
#        [0.75607726, 0.73948413, 0.73258668],
#        [1.        , 0.91480342, 0.90871795],
#        [1.        , 0.91480342, 0.90871795]])

# %%
names2_ind = names2.index

# %%
string_NN_indices = names2_ind.values[dist_mat.argsort()[:,-3:]]

# %%
np.apply_along_axis(lambda x: names2.loc[x], 1, string_NN_indices)
# Out:
# array([['TUNASAN ELEMENTARY SCHOOL', 'PINAGBUHATAN ELEMENTARY SCHOOL',
#         'PINYAHAN ELEMENTARY SCHOOL'],
#        ['TUNASAN ELEMENTARY SCHOOL', 'PINAGBUHATAN ELEMENTARY SCHOOL',
#         'PINYAHAN ELEMENTARY SCHOOL'],
#        ['GEN PIO DEL PILAR NATIONAL HIGH SCHOOL',
#         'CAMP GEN E AGUINALDO HIGH SCHOOL',
#         'JUDGE FELICIANO BELMONTE SR HIGH SCHOOL'],
#        ...,
#        ['JOSE ABAD SANTOS HIGH SCHOOL',
#         'PRES SERGIO OSMENA SR HIGH SCHOOL',
#         'SERGIO OSMENA SR HIGH SCHOOL'],
#        ['F AMORSOLO ELEMENTARY SCHOOL', 'HOLY SPIRIT ELEMENTARY SCHOOL',
#         'TORO HILLS ELEMENTARY SCHOOL'],
#        ['VERGONVILLE ELEMENTARY SCHOOL',
#         'VILLAMOR AIRBASE ELEMENTARY SCHOOL',
#         'VILLA VERDE ELEMENTARY SCHOOL']], dtype=object)

# %%
names2.loc[string_NN_indices]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-a2bb885074da> in <module>
# ----> 1 names2.loc[string_NN_indices]
#
# C:\WBG\Anaconda3\envs\conn\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# C:\WBG\Anaconda3\envs\conn\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1835
#    1836                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
#    1839                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
(dist_mat.max(axis = 1)>=0.90).mean()
# Out:
# 0.7339901477832512

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(pd.DataFrame(zip(names1_l,np.array(names2_l)[dist_mat.argmax(axis = 1)], dist_mat.max(axis=1))))
# Out:
#                                                      0  \
# 0                           PINYAHAN ELEMENTARY SCHOOL
# 1                           PINYAHAN ELEMENTARY SCHOOL
# 2           SEDP BUILDING 8CL MANUEL ROXAS HIGH SCHOOL
# 3                             MANUEL ROXAS HIGH SCHOOL
# 4                             MANUEL ROXAS HIGH SCHOOL
# 5                             MALAYA ELEMENTARY SCHOOL
# 6                      KRUS NA LIGAS ELEMENTARY SCHOOL
# 7                       TOMAS MORATO ELEMENTARY SCHOOL
# 8                       TOMAS MORATO ELEMENTARY SCHOOL
# 9                       MH DEL PILAR ELEMENTARY SCHOOL
# 10                      MH DEL PILAR ELEMENTARY SCHOOL
# 11                      MH DEL PILAR ELEMENTARY SCHOOL
# 12                           KRUS NA LIGAS HIGH SCHOOL
# 13                             QUEZON CITY HIGH SCHOOL
# 14                                 QUIRINO HIGH SCHOOL
# 15                         BAGONG SILANGAN HIGH SCHOOL
# ...

# %%
most_similar_indi = cosine_similarity(CountVectorizer().fit_transform(names1_l + names2_l).toarray())[0:len(names1),len(names1):].argmax(axis = 1)

pd.DataFrame({'Name 1': names1_l , 'Name 2': np.array(names1_l + names2_l)[most_similar_indi]})
# Out:
#                                                 Name 1  \
# 0    BAGONG LIPUNAN BUILDING 2 6CL PINYAHAN ELEMENT...
# 1    SANLAKAS BUILDING 6CL PINYAHAN ELEMENTARY SCHO...
# 2    SEDP BUILDING 8CL MANUEL ROXAS HIGH SCHOOL SCT...
# 3    SB BUILDING 8CL MANUEL ROXAS HIGH SCHOOL SCT C...
# 4    PROPERTY BUILDING LIBRARY AND PROPERTY 4CL MAN...
# ..                                                 ...
# 401  MATHAY BUILDING NEW ERA ELEMENTARY SCHOOL TAND...
# 402  DPWH BUILDING ROSA L SUSANO ELEMENTARY SCHOOL ...
# 403  CALALAY BUILDING SERGIO OSMENA SR HIGH SCHOOL ...
# 404  ADMIN BUILDING TORO HILLS ELEMENTARY SCHOOL RO...
# 405  BELMONTE HALL VILLA VERDE ELEMENTARY SCHOOL VI...
#
#                                                 Name 2
# 0                         GATCHALIAN ELEMENTARY SCHOOL
# 1                         GATCHALIAN ELEMENTARY SCHOOL
# 2    MATHAY BUILDING 12CL MH DEL PILAR ELEMENTARY S...
# 3    MATHAY BUILDING 12CL MH DEL PILAR ELEMENTARY S...
# ...

# %%
name = ' Pinagbuhatan Elementary School'

# %%
clean_words = ['school', 'elementary', 'es']

# %%
replace_dict = {'ES': 'elementary school',
               'HS': 'high school'}
'high school' in replace_dict
# Out:
# False

# %%
replace_dict['ES']
# Out:
# 'elementary school'

# %%
from difflib import get_close_matches 
get_close_matches('Pinagb', x.split(), n = 1, cutoff = 0.2)
# Out:
# ['Pinagbuhatan']

# %%
clean_name(' Pinagbuhatan Tiñga ES', replace_dict={'ES': 'elementary school'})
# Out:
# 'PINAGBUHATAN TIÑGA ELEMENTARY SCHOOL'

# %%
def clean_name(name, clean_words):
    clean_name = []
    for x in name.split():
        word = x.strip().lower()
        if word not in clean_words:
            word = clean_name.append(word)
    return ' '.join(clean_name)

# %%
test_loc = GeoJSONDataSource(geojson = selec_hos_u_p_combn.drop(columns = 'NN_geometry').to_crs(lonlat_crs).to_json())

# %%
tile_provider = get_provider(CARTODBPOSITRON)

# %%
p = figure(title = 'Test map')
p.circle('x','y', source = test_loc)
p.add_tile(tile_provider)
show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-160-0068757a72ff> in <module>
#       2 p.circle('x','y', source = test_loc)
#       3 p.add_tile(tile_provider)
# ----> 4 show(p)
#
# C:\WBG\Anaconda3\envs\conn\lib\site-packages\bokeh\io\showing.py in show(obj, browser, new, notebook_handle, notebook_url, **kw)
#     137         return run_notebook_hook(state.notebook_type, 'app', obj, state, notebook_url, **kw)
#     138
# --> 139     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     140
#     141 #-----------------------------------------------------------------------------
#
# C:\WBG\Anaconda3\envs\conn\lib\site-packages\bokeh\io\showing.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     175
#     176     if state.file or not shown:
# --> 177         _show_file_with_state(obj, state, new, controller)
# ...

# %% [markdown]
# *Ensure that spatial data remains*:

# %%
nn_index(slec_sch_u_p,mani_sch_p, k = 1)
# Out:
#       index_k_1    dist_k_1
# 0           518  789.312559
# 1           518  789.312559
# 2           518  227.594759
# 3           518  789.312559
# 4           471  246.384491
# ...         ...         ...
# 1266        549  362.018230
# 1267        435  649.100242
# 1268        435  649.100242
# 1269        435  649.100242
# 1270        557   43.689181
#
# [1185 rows x 2 columns]

# %%
#Copy data:
gdf1 = mani_hos_p
gdf2 = selec_hos_p

# %%
gd1 = gdf1.copy()
gd2 = gdf2.copy()
    
#Add coordi
gd1['X1'] = gd1.geometry.x
gd1['Y1'] = gd1.geometry.y
    
gd2['X2'] = gd2.geometry.x
gd2['Y2'] = gd2.geometry.y
    
    
## NN lookup
#Import spatial from scipy for very quick NN lookup:
from scipy import spatial
G_tree = spatial.KDTree(gd1[['X1','Y1']].values)
distances, indices = G_tree.query(gd2[['X2','Y2']].values, k=2)

# %%
pd.Series(distances[:,0]).plot(kind = 'hist')

# %%
# Add coordinates of neigherst neighbor:
mapped_hos = gd2.reset_index(drop = True).merge(gd1.loc[indices[:,0],cols].reset_index(drop = True).rename(columns = {'geometry': 'n_geometry'}),
                                  left_index = True, right_index = True)

# %%
indices[:,]
# Out:
# array([[497, 479],
#        [633, 683],
#        [478, 544],
#        [633, 683],
#        [633, 683],
#        [ 30, 487],
#        [ 30, 487],
#        [ 30, 487],
#        [ 30, 487],
#        [530, 513],
#        [532, 559],
#        [532, 559],
#        [542, 513],
#        [532, 559],
#        [542, 513],
#        [312, 308],
#        [312, 308],
#        [312, 308],
#        [312, 308],
#        [327, 338],
#        [327, 338],
#        [327, 338],
#        [396, 377],
#        [396, 377],
#        [396, 377],
#        [206, 200],
#        [149, 151],
#        [691, 715],
#        [165, 162],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  13],
#        [ 66,  64],
#        [ 66,  64],
#        [ 66,  64],
#        [ 65,  66],
#        [ 65,  66],
#        [ 65,  66],
#        [ 65,  66],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  10],
#        [ 12,  10],
#        [ 12,  10],
# ...

# %%
gd1.index.values[indices]
# Out:
# array([[497, 479],
#        [633, 683],
#        [478, 544],
#        [633, 683],
#        [633, 683],
#        [ 30, 487],
#        [ 30, 487],
#        [ 30, 487],
#        [ 30, 487],
#        [530, 513],
#        [532, 559],
#        [532, 559],
#        [542, 513],
#        [532, 559],
#        [542, 513],
#        [312, 308],
#        [312, 308],
#        [312, 308],
#        [312, 308],
#        [327, 338],
#        [327, 338],
#        [327, 338],
#        [396, 377],
#        [396, 377],
#        [396, 377],
#        [206, 200],
#        [149, 151],
#        [691, 715],
#        [165, 162],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  13],
#        [ 66,  64],
#        [ 66,  64],
#        [ 66,  64],
#        [ 65,  66],
#        [ 65,  66],
#        [ 65,  66],
#        [ 65,  66],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  13],
#        [ 12,  10],
#        [ 12,  10],
#        [ 12,  10],
# ...

# %%
mapped_hos
# Out:
#      Object_ID   City_Addre  \
# 0           30  Quezon City
# 1           31  Quezon City
# 2           32  Quezon City
# 3           33  Quezon City
# 4           34  Quezon City
# ..         ...          ...
# 97        1283  Quezon City
# 98        1284  Quezon City
# 99        1285  Quezon City
# 100       1286     San Juan
# 101       1287       Taguig
#
#                                             Building_N  \
# 0    Phase 1  Building, Quirino Memorial Medical Ce...
# 1    Phase 2 Building, Quirino Memorial Medical Cen...
# 2    Phase 4 Building, Quirino Memorial Medical Cen...
# 3    Phase 6 Building (Admin & 2A), Quirino Memoria...
# 4    Phase 6 Building (OPD and ER), Quirino Memoria...
# ..                                                 ...
# 97   OPD Building, PNP General Hospital,  P. Tuazon...
# 98   Surgical Building, PNP General Hospital,  P. T...
# 99   Ward Building, PNP General Hospital,  P. Tuazo...
# 100  San Juan Medical Center, N. Domingo St., San J...
# ...

# %%
gd2['Building_N']
# Out:
# 29      Phase 1  Building, Quirino Memorial Medical Ce...
# 30      Phase 2 Building, Quirino Memorial Medical Cen...
# 31      Phase 4 Building, Quirino Memorial Medical Cen...
# 32      Phase 6 Building (Admin & 2A), Quirino Memoria...
# 33      Phase 6 Building (OPD and ER), Quirino Memoria...
#                               ...
# 1282    OPD Building, PNP General Hospital,  P. Tuazon...
# 1283    Surgical Building, PNP General Hospital,  P. T...
# 1284    Ward Building, PNP General Hospital,  P. Tuazo...
# 1285    San Juan Medical Center, N. Domingo St., San J...
# 1286    Army General Hospital, Fort A. Bonifacio, Tagu...
# Name: Building_N, Length: 102, dtype: object

# %%
gd1.iloc[1,:]
# Out:
# objectid                                                   7492
# joincount                                                     1
# targetfid                                                  8180
# facilityc                                    DOH000000000000314
# healthfac                                                   314
# facilityn                               NODADO GENERAL HOSPITAL
# healthf1                                               Hospital
# ownership                                               Private
# ownership1                                                 None
# streetname                                                 None
# buildingn                                                  None
# zipcode                                                    3013
# landlinen                                         +63 449385997
# landline1                                                  None
# faxnumber                                         +63 448150754
# ...

# %%
len(selec_hos_p)
# Out:
# 102

# %% [markdown]
# Code for nearest neighbor mapping:

# %%
pd.DataFrame(np.array([gd1.geometry.x, gd1.geometry.y]).T, columns= ['X','Y'])

np.column_stack([np.array([gd1.geometry.x, gd1.geometry.y]).T, np.array([gd1.geometry.x, gd1.geometry.y]).T])
# Out:
# array([[ 498114.09438947, 1630659.09421765,  498114.09438947,
#         1630659.09421765],
#        [ 504967.71840572, 1629993.89614141,  504967.71840572,
#         1629993.89614141],
#        [ 496825.91428374, 1614475.29508726,  496825.91428374,
#         1614475.29508726],
#        ...,
#        [ 496193.59123715, 1627263.25801086,  496193.59123715,
#         1627263.25801086],
#        [ 501171.44679089, 1625334.96147453,  501171.44679089,
#         1625334.96147453],
#        [ 492289.51690536, 1629286.79921567,  492289.51690536,
#         1629286.79921567]])

# %%
base = mani_hos.plot(figsize = (20,20), alpha = 0.6)
gmma_hos.plot(ax = base, color = 'red', markersize = 1)
selec_buil[selec_buil['Type_Occup']=='Hospitals and Facilities'].plot(ax = base, color = 'violet', markersize = 10)
